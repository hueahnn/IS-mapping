# %% [markdown]
# # July 30, 2026
# * Validating IS coverage script

# %%
import polars as pl
cov_df = pl.read_csv("/n/scratch/users/h/hua575/atb_filtered/is_coverage/is_coverage_table.tsv", separator="\t")

# %%
# spot check a few
genome = "SRR31591377"
insertion_seq = "IS2"

sub_df = cov_df.filter(
    (pl.col("genome_accession") == genome) & 
    (pl.col("is_element") == insertion_seq)
)

# %%
genome = "ERR10391393"

sub_df = cov_df.filter(  
    (pl.col("genome_accession") == genome) 
)
